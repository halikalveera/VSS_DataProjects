# %% [markdown]
# <a href="https://colab.research.google.com/github/halikalveera/VSS_DataProjects/blob/Master/Basics_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "John"
age = 30
salary = 75000.00
is_analyst = True

print(name)      # John
print(age)       # 30
print(salary)
print(is_analyst)
# Out:
# John
# 30
# 75000.0
# True

# %%
# Data types

# Python has four basic types you need to know:
# String — text, always in quotes
job_title = "Data Analyst"

# Integer — whole number
years_experience = 3

# Float — decimal number
conversion_rate = 0.045

# Boolean — True or False only
has_python_skills = True

# %%
# Lists - A list is a collection of items in a specific order.

skills = ["SQL", "Python", "Power BI", "Excel"]

print(skills[0])    # SQL — Python counts from 0, not 1
print(skills[2])    # Power BI
print(len(skills))  # 4 — how many items in the list
# Out:
# SQL
# Power BI
# 4

# %%
# If statements - If statements make decisions.
salary = 80000

if salary > 100000:
    print("Senior level")
elif salary > 60000:
    print("Mid level")
else:
    print("Junior level")
# Out:
# Mid level

# %%
# Loops - A loop repeats something. Instead of writing the same thing ten times, you write it once and tell Python to repeat it.
skills = ["SQL", "Python", "Power BI", "Excel"]

for skill in skills:
    print("I know", skill)
# Out:
# I know SQL
# I know Python
# I know Power BI
# I know Excel

# %%
# Functions - A function is a reusable block of code. You define it once, use it many times.
def greet_analyst(name):
    print("Welcome to the team,", name)

greet_analyst("Josh")    # Welcome to the team, Josh
greet_analyst("Alex")      # Welcome to the team, Alex
# Out:
# Welcome to the team, Josh
# Welcome to the team, Alex

# %%
# Your first real task - Try this in Google Colab right now.
# Create a list of your top 5 skills
my_skills = ["SQL", "Excel", "Power BI", "Python", "Data Visualisation"]

# Loop through and print each one
for i, skill in enumerate(my_skills, 1):
    print(f"{i}. {skill}")
# Out:
# 1. SQL
# 2. Excel
# 3. Power BI
# 4. Python
# 5. Data Visualisation
